# %%
# !pip install crewai crewai_tools langchain_community
# Out:
# Requirement already satisfied: crewai in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (0.102.0)
# Requirement already satisfied: crewai_tools in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (0.36.0)
# Requirement already satisfied: langchain_community in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (0.3.17)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.4.4)
# Requirement already satisfied: auth0-python>=4.7.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (4.8.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.9.0)
# Requirement already satisfied: chromadb>=0.5.23 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (0.5.23)
# Requirement already satisfied: click>=8.1.7 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (8.1.8)
# Requirement already satisfied: instructor>=1.3.3 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.7.2)
# Requirement already satisfied: json-repair>=0.25.2 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (0.37.0)
# Requirement already satisfied: json5>=0.10.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (0.10.0)
# Requirement already satisfied: jsonref>=1.1.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.1.0)
# Requirement already satisfied: litellm==1.60.2 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.60.2)
# Requirement already satisfied: openai>=1.13.3 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.61.0)
# Requirement already satisfied: openpyxl>=3.1.5 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (3.1.5)
# Requirement already satisfied: opentelemetry-api>=1.22.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.30.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.22.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.30.0)
# Requirement already satisfied: opentelemetry-sdk>=1.22.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.30.0)
# Requirement already satisfied: pdfplumber>=0.11.4 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (0.11.5)
# Requirement already satisfied: pydantic>=2.4.2 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (2.10.6)
# Requirement already satisfied: python-dotenv>=1.0.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.0.0)
# Requirement already satisfied: pyvis>=0.3.2 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (0.3.2)
# Requirement already satisfied: regex>=2024.9.11 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (2024.11.6)
# Requirement already satisfied: tomli-w>=1.1.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.2.0)
# Requirement already satisfied: tomli>=2.0.2 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (2.2.1)
# Requirement already satisfied: uv>=0.4.25 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai) (0.6.0)
# Requirement already satisfied: aiohttp in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from litellm==1.60.2->crewai) (3.11.12)
# Requirement already satisfied: httpx<0.28.0,>=0.23.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from litellm==1.60.2->crewai) (0.27.2)
# Requirement already satisfied: importlib-metadata>=6.8.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from litellm==1.60.2->crewai) (8.5.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from litellm==1.60.2->crewai) (3.1.5)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from litellm==1.60.2->crewai) (4.23.0)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from litellm==1.60.2->crewai) (0.7.0)
# Requirement already satisfied: tokenizers in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from litellm==1.60.2->crewai) (0.21.0)
# Requirement already satisfied: docker>=7.1.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai_tools) (7.1.0)
# Requirement already satisfied: embedchain>=0.1.114 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai_tools) (0.1.126)
# Requirement already satisfied: lancedb>=0.5.4 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai_tools) (0.5.7)
# Requirement already satisfied: pyright>=1.1.350 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai_tools) (1.1.394)
# Requirement already satisfied: pytube>=15.0.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai_tools) (15.0.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from crewai_tools) (2.32.3)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.34 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (0.3.35)
# Requirement already satisfied: langchain<1.0.0,>=0.3.18 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (0.3.18)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (2.0.38)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (9.0.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (2.7.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (0.1.147)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (0.4.0)
# Requirement already satisfied: numpy<2,>=1.26.4 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->litellm==1.60.2->crewai) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->litellm==1.60.2->crewai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->litellm==1.60.2->crewai) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->litellm==1.60.2->crewai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->litellm==1.60.2->crewai) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->litellm==1.60.2->crewai) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->litellm==1.60.2->crewai) (1.18.3)
# Requirement already satisfied: cryptography>=43.0.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from auth0-python>=4.7.1->crewai) (44.0.1)
# Requirement already satisfied: pyjwt>=2.8.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from auth0-python>=4.7.1->crewai) (2.10.1)
# Requirement already satisfied: urllib3>=2.2.3 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from auth0-python>=4.7.1->crewai) (2.3.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (0.115.8)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.34.0)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (3.13.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (1.20.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (1.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (0.51b0)
# Collecting tokenizers (from litellm==1.60.2->crewai)
#   Using cached tokenizers-0.20.3-cp311-none-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (1.70.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (0.9.4)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (32.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (3.10.15)
# Requirement already satisfied: rich>=10.11.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (13.9.4)
# Requirement already satisfied: colorama in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from click>=8.1.7->crewai) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: pywin32>=304 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from docker>=7.1.0->crewai_tools) (308)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from embedchain>=0.1.114->crewai_tools) (1.14.1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.2 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from embedchain>=0.1.114->crewai_tools) (4.13.3)
# Requirement already satisfied: cohere<6.0,>=5.3 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from embedchain>=0.1.114->crewai_tools) (5.13.12)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.26.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from embedchain>=0.1.114->crewai_tools) (1.80.0)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from embedchain>=0.1.114->crewai_tools) (0.1.44)
# Requirement already satisfied: langchain-cohere<0.4.0,>=0.3.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from embedchain>=0.1.114->crewai_tools) (0.3.5)
# Requirement already satisfied: langchain-openai<0.3.0,>=0.2.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from embedchain>=0.1.114->crewai_tools) (0.2.14)
# Requirement already satisfied: mem0ai<0.2.0,>=0.1.37 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from embedchain>=0.1.114->crewai_tools) (0.1.49)
# Requirement already satisfied: pypdf<6.0.0,>=5.0.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from embedchain>=0.1.114->crewai_tools) (5.3.0)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from embedchain>=0.1.114->crewai_tools) (0.3.4)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from embedchain>=0.1.114->crewai_tools) (0.7.5)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from instructor>=1.3.3->crewai) (0.16)
# Requirement already satisfied: jiter<0.9,>=0.6.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from instructor>=1.3.3->crewai) (0.8.2)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from instructor>=1.3.3->crewai) (2.27.2)
# Requirement already satisfied: deprecation in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from lancedb>=0.5.4->crewai_tools) (2.1.0)
# Requirement already satisfied: pylance==0.9.18 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from lancedb>=0.5.4->crewai_tools) (0.9.18)
# Requirement already satisfied: ratelimiter~=1.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from lancedb>=0.5.4->crewai_tools) (1.2.0.post0)
# Requirement already satisfied: retry>=0.9.2 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from lancedb>=0.5.4->crewai_tools) (0.9.2)
# Requirement already satisfied: semver>=3.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from lancedb>=0.5.4->crewai_tools) (3.0.4)
# Requirement already satisfied: cachetools in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from lancedb>=0.5.4->crewai_tools) (5.5.1)
# Requirement already satisfied: pyarrow>=12 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from pylance==0.9.18->lancedb>=0.5.4->crewai_tools) (19.0.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain<1.0.0,>=0.3.18->langchain_community) (0.3.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain_community) (23.2)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from openai>=1.13.3->crewai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from openai>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from openai>=1.13.3->crewai) (1.3.1)
# Requirement already satisfied: et-xmlfile in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from openpyxl>=3.1.5->crewai) (2.0.0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-api>=1.22.0->crewai) (1.2.18)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.67.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.30.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.30.0)
# Requirement already satisfied: opentelemetry-proto==1.30.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.30.0)
# Requirement already satisfied: protobuf<6.0,>=5.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-proto==1.30.0->opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (5.29.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-sdk>=1.22.0->crewai) (0.51b0)
# Requirement already satisfied: pdfminer.six==20231228 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from pdfplumber>=0.11.4->crewai) (20231228)
# Requirement already satisfied: Pillow>=9.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from pdfplumber>=0.11.4->crewai) (11.0.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from pdfplumber>=0.11.4->crewai) (4.30.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from pdfminer.six==20231228->pdfplumber>=0.11.4->crewai) (3.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.4.2->crewai) (0.7.0)
# Requirement already satisfied: nodeenv>=1.6.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from pyright>=1.1.350->crewai_tools) (1.9.1)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from pyvis>=0.3.2->crewai) (8.32.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from pyvis>=0.3.2->crewai) (4.0.1)
# Requirement already satisfied: networkx>=1.11 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from pyvis>=0.3.2->crewai) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31.0->crewai_tools) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31.0->crewai_tools) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.1.1)
# Requirement already satisfied: Mako in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from alembic<2.0.0,>=1.13.1->embedchain>=0.1.114->crewai_tools) (1.3.9)
# Requirement already satisfied: soupsieve>1.2 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.2->embedchain>=0.1.114->crewai_tools) (2.6)
# Requirement already satisfied: pyproject_hooks in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (1.2.0)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai_tools) (1.10.0)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai_tools) (2.32.0.20241016)
# Requirement already satisfied: cffi>=1.12 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from cryptography>=43.0.1->auth0-python>=4.7.1->crewai) (1.17.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.22.0->crewai) (1.17.2)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from fastapi>=0.95.2->chromadb>=0.5.23->crewai) (0.41.3)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools) (2.24.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools) (1.26.0)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools) (3.29.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools) (1.14.0)
# Requirement already satisfied: shapely<3.0.0dev in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools) (2.0.7)
# Requirement already satisfied: httpcore==1.* in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from httpx<0.28.0,>=0.23.0->litellm==1.60.2->crewai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<0.28.0,>=0.23.0->litellm==1.60.2->crewai) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata>=6.8.0->litellm==1.60.2->crewai) (3.21.0)
# Requirement already satisfied: decorator in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.18.0)
# Requirement already satisfied: stack_data in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.14.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from jinja2<4.0.0,>=3.1.2->litellm==1.60.2->crewai) (3.0.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.34->langchain_community) (3.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.60.2->crewai) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.60.2->crewai) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.60.2->crewai) (0.22.3)
# Requirement already satisfied: six>=1.9.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.9)
# Requirement already satisfied: langchain-experimental<0.4.0,>=0.3.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai_tools) (0.3.4)
# Requirement already satisfied: pandas>=1.4.3 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai_tools) (2.2.3)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai_tools) (0.9.0)
# Requirement already satisfied: pytz<2025.0,>=2024.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from mem0ai<0.2.0,>=0.1.37->embedchain>=0.1.114->crewai_tools) (2024.2)
# Requirement already satisfied: qdrant-client<2.0.0,>=1.9.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from mem0ai<0.2.0,>=0.1.37->embedchain>=0.1.114->crewai_tools) (1.13.2)
# Requirement already satisfied: coloredlogs in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (25.2.10)
# Requirement already satisfied: sympy in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (1.13.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.51b0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.51b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.51b0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.51b0)
# Requirement already satisfied: opentelemetry-util-http==0.51b0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.51b0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-asgi==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai) (2.2.1)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from retry>=0.9.2->lancedb>=0.5.4->crewai_tools) (1.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai) (3.0.0)
# Requirement already satisfied: contextlib2>=0.5.5 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from schema<0.8.0,>=0.7.5->embedchain>=0.1.114->crewai_tools) (21.6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from tokenizers->litellm==1.60.2->crewai) (0.28.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (15.0)
# Requirement already satisfied: pycparser in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.12->cryptography>=43.0.1->auth0-python>=4.7.1->crewai) (2.22)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools) (1.70.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=2.4.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=2.0.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools) (2.7.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools) (0.14.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools) (1.6.0)
# Requirement already satisfied: filelock in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm==1.60.2->crewai) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm==1.60.2->crewai) (2025.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.23->crewai) (0.1.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.4.3->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai_tools) (2025.1)
# Requirement already satisfied: wcwidth in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.13)
# Requirement already satisfied: grpcio-tools>=1.41.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.37->embedchain>=0.1.114->crewai_tools) (1.70.0)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.37->embedchain>=0.1.114->crewai_tools) (2.10.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (10.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (1.3.0)
# Requirement already satisfied: setuptools in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from grpcio-tools>=1.41.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.37->embedchain>=0.1.114->crewai_tools) (65.5.0)
# Requirement already satisfied: h2<5,>=3 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.37->embedchain>=0.1.114->crewai_tools) (4.2.0)
# Requirement already satisfied: pyreadline3 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools) (0.6.1)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.37->embedchain>=0.1.114->crewai_tools) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.37->embedchain>=0.1.114->crewai_tools) (4.1.0)
# Using cached tokenizers-0.20.3-cp311-none-win_amd64.whl (2.4 MB)
# Installing collected packages: tokenizers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.0
#     Uninstalling tokenizers-0.21.0:
#       Successfully uninstalled tokenizers-0.21.0
# Successfully installed tokenizers-0.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 4.48.3 requires tokenizers<0.22,>=0.21, but you have tokenizers 0.20.3 which is incompatible.
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\laksh\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
# !pip install langchain-groq
# Out:
# Requirement already satisfied: langchain-groq in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (0.2.4)
# Requirement already satisfied: groq<1,>=0.4.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain-groq) (0.18.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.33 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain-groq) (0.3.35)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (0.27.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (2.10.6)
# Requirement already satisfied: sniffio in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (4.12.2)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<0.4.0,>=0.3.33->langchain-groq) (0.1.147)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<0.4.0,>=0.3.33->langchain-groq) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<0.4.0,>=0.3.33->langchain-groq) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<0.4.0,>=0.3.33->langchain-groq) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<0.4.0,>=0.3.33->langchain-groq) (23.2)
# Requirement already satisfied: idna>=2.8 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (3.10)
# Requirement already satisfied: certifi in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.33->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain-groq) (3.10.15)
# Requirement already satisfied: requests<3,>=2 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain-groq) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain-groq) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain-groq) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain-groq) (2.3.0)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\laksh\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (3.4.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (4.48.3)
# Requirement already satisfied: tqdm in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (2.6.0)
# Requirement already satisfied: scikit-learn in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (1.15.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (0.28.1)
# Requirement already satisfied: Pillow in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (11.0.0)
# Requirement already satisfied: filelock in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.2.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: networkx in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.5)
# Requirement already satisfied: sympy==1.13.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Collecting tokenizers<0.22,>=0.21 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Using cached tokenizers-0.21.0-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laksh\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.1.31)
# Using cached tokenizers-0.21.0-cp39-abi3-win_amd64.whl (2.4 MB)
# Installing collected packages: tokenizers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.20.3
#     Uninstalling tokenizers-0.20.3:
#       Successfully uninstalled tokenizers-0.20.3
# Successfully installed tokenizers-0.21.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chromadb 0.5.23 requires tokenizers<=0.20.3,>=0.13.2, but you have tokenizers 0.21.0 which is incompatible.
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\laksh\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
from langchain_openai import ChatOpenAI
import os
from crewai_tools import PDFSearchTool
from langchain_community.tools.tavily_search import TavilySearchResults
from crewai.tools  import tool
from crewai import Crew
from crewai import Task
from crewai import Agent

# %%
llm = ChatOpenAI(
    openai_api_base="https://api.groq.com/openai/v1",
    openai_api_key=os.environ['OPENAI_API_KEY'],
    model_name="gpt-4o",
    temperature=0.1,
    max_tokens=1000,
)

# %%
rag_tool = PDFSearchTool(pdf='random_qa.pdf',
    config=dict(
        llm=dict(
            provider="openai", # or google, openai, anthropic, llama2, ...
            config=dict(
                model="gpt-4o",
                # temperature=0.5,
                # top_p=1,
                # stream=true,
            ),
        ),
        embedder=dict(
            provider="openai", # or openai, ollama, ...
            config=dict(
                model="text-embedding-ada-002",
                #task_type="retrieval_document",
                # title="Embeddings",
            ),
        ),
    )
)
# Out:
# Inserting batches in chromadb: 100%|█████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.40s/it]

# %%
rag_tool.run("Which continent is the Sahara Desert located in?")
# Out:
# Using Tool: Search a PDF's content
# "Relevant Content:\nQ14: Which continent is the Sahara Desert located in? A14: Africa Q15: What is the main ingredient in guacamole? A15: Avocado Q16: How many hearts does an octopus have? A16: Three Q17: What is the hardest natural substance on Earth? A17: Diamond Q18: Who is the CEO of Tesla (as of 2024)? A18: Elon Musk Q19: What is the speed of light in a vacuum? A19: 299,792,458 meters per second Q20: Which gas do plants primarily absorb from the atmosphere? A20: Carbon dioxide (CO2)\n\nRandom Question-Answer Pairs Q1: What is the capital of Canada? A1: Ottawa Q2: Who developed the theory of relativity? A2: Albert Einstein Q3: What is the largest planet in our solar system? A3: Jupiter Q4: Which programming language is primarily used for AI and machine learning? A4: Python Q5: What does HTTP stand for? A5: Hypertext Transfer Protocol Q6: Who wrote 'To Kill a Mockingbird'? A6: Harper Lee Q7: What is the square root of 144? A7: 12 Q8: Which company created the iPhone? A8: Apple Q9: What is the boiling point of water in Celsius? A9: 100°C Q10: Who painted the Mona Lisa? A10: Leonardo da Vinci Q11: What is the currency of Japan? A11: Japanese Yen (JPY) Q12: What year did World War II end? A12: 1945 Q13: What is the chemical symbol for gold? A13: Au"

# %%
web_search_tool.run(" Which continent is the Sahara Desert located in?")
# Out:
# [{'url': 'https://www.toppr.com/ask/question/answer-the-following-questions-brieflyin-which-continent-is-the-sahara/',
#   'content': 'The Sahara desert is located across Northern Africa and covers approximately 25 percent of the African continent. Its borders include the Mediterranean Sea'},
#  {'url': 'https://www.vedantu.com/question-answer/in-which-continent-is-the-sahara-desert-located-class-10-social-science-cbse-600506b28f072d242817b4b2',
#   'content': 'This Sahara Desert is located on the African continent. It is bordered to the south by the Sahel, a region of semi-arid tropical savannah across the valley of'},
#  {'url': 'https://en.wikipedia.org/wiki/Sahara_desert_(ecoregion)',
#   'content': "Setting. The Sahara Desert is the world's largest hot, non-polar desert and is located in North Africa. It extends from the Atlantic Ocean in the west to the"},
#  {'url': 'https://www.globaladventurechallenges.com/journal/facts-about-sahara-desert',
#   'content': 'Located in North Africa, it covers large sections of the continent - covering 9,200,000 square kilometers which is comparable to the are of China or the US!'},
#  {'url': 'https://byjus.com/question-answer/sahara-desert-is-located-in-which-part-of-africa/',
#   'content': "Sahara desert is located in Northern part of Africa. Also, it is the world's largest desert. Q. Tick the correct answer:"}]

# %%
@tool
def router_tool():
    """Router Function"""
    return 'vectorstore'
 # if ' ' in question:

 # else:
   # return 'web_search'

# %%
Router_Agent = Agent(
  role='Router',
  goal='Route user question to a vectorstore',
  backstory=(
    "You are an expert at routing a user question to a vectorstore"
    "Use the vectorstore for questions on concept related to Retrieval-Augmented Generation."
    "You do not need to be stringent with the keywords in the question related to these topics."
  ),
  verbose=True,
  allow_delegation=False,
  llm=llm,
)

# %%
Retriever_Agent = Agent(
role="Retriever",
goal="Use the information retrieved from the vectorstore to answer the question",
backstory=(
    "You are an assistant for question-answering tasks."
    "Use the information present in the retrieved context to answer the question."
    "You have to provide a clear concise answer."
),
verbose=True,
allow_delegation=False,
llm=llm,
)

# %%
Grader_agent =  Agent(
  role='Answer Grader',
  goal='Filter out erroneous retrievals',
  backstory=(
    "You are a grader assessing relevance of a retrieved document to a user question."
    "If the document contains keywords related to the user question, grade it as relevant."
    "It does not need to be a stringent test.You have to make sure that the answer is relevant to the question."
  ),
  verbose=True,
  allow_delegation=False,
  llm=llm,
)

# %%
hallucination_grader = Agent(
    role="Hallucination Grader",
    goal="Filter out hallucination",
    backstory=(
        "You are a hallucination grader assessing whether an answer is grounded in / supported by a set of facts."
        "Make sure you meticulously review the answer and check if the response provided is in alignmnet with the question asked"
    ),
    verbose=True,
    allow_delegation=False,
    llm=llm,
)

# %%
answer_grader = Agent(
    role="Answer Grader",
    goal="Filter out hallucination from the answer.",
    backstory=(
        "You are a grader assessing whether an answer is useful to resolve a question."
        "Make sure you meticulously review the answer and check if it makes sense for the question asked"
        "If the answer is relevant generate a clear and concise response."
        "If the answer gnerated is not relevant then perform a websearch using 'web_search_tool'"
    ),
    verbose=True,
    allow_delegation=False,
    llm=llm,
)

# %%
router_task = Task(
    description=("Analyse the keywords in the question {question}"
    "Based on the keywords decide whether it is eligible for a vectorstore search"
    "Return a single word 'vectorstore' if it is eligible for vectorstore search."
    "Do not provide any other premable or explaination."
    ),
    expected_output=('vectorstore'),
    agent=Router_Agent,
    tools=[router_tool],
)

# %%
retriever_task = Task(
    description=("Based on the response from the router task extract information for the question {question} with the help of the respective tool."
    "Use the web_serach_tool to retrieve information from the web in case the router task output is 'websearch'."
    "Use the rag_tool to retrieve information from the vectorstore in case the router task output is 'vectorstore'."
    ),
    expected_output=("You should analyse the output of the 'router_task'"
    "If the response is 'websearch' then use the web_search_tool to retrieve information from the web."
    "If the response is 'vectorstore' then use the rag_tool to retrieve information from the vectorstore."
    "Return a claer and consise text as response."),
    agent=Retriever_Agent,
    context=[router_task],
   #tools=[retriever_tool],
)

# %%
grader_task = Task(
    description=("Based on the response from the retriever task for the quetion {question} evaluate whether the retrieved content is relevant to the question."
    ),
    expected_output=("Binary score 'yes' or 'no' score to indicate whether the document is relevant to the question"
    "You must answer 'yes' if the response from the 'retriever_task' is in alignment with the question asked."
    "You must answer 'no' if the response from the 'retriever_task' is not in alignment with the question asked."
    "Do not provide any preamble or explanations except for 'yes' or 'no'."),
    agent=Grader_agent,
    context=[retriever_task],
)

# %%
hallucination_task = Task(
    description=("Based on the response from the grader task for the quetion {question} evaluate whether the answer is grounded in / supported by a set of facts."),
    expected_output=("Binary score 'yes' or 'no' score to indicate whether the answer is sync with the question asked"
    "Respond 'yes' if the answer is in useful and contains fact about the question asked."
    "Respond 'no' if the answer is not useful and does not contains fact about the question asked."
    "Do not provide any preamble or explanations except for 'yes' or 'no'."),
    agent=hallucination_grader,
    context=[grader_task],
)

answer_task = Task(
    description=("Based on the response from the hallucination task for the quetion {question} evaluate whether the answer is useful to resolve the question."
    "If the answer is 'yes' return a clear and concise answer."
    "If the answer is 'no' then perform a 'websearch' and return the response"),
    expected_output=("Return a clear and concise response if the response from 'hallucination_task' is 'yes'."
    "Perform a web search using 'web_search_tool' and return ta clear and concise response only if the response from 'hallucination_task' is 'no'."
    "Otherwise respond as 'Sorry! unable to find a valid response'."),
    context=[hallucination_task],
    agent=answer_grader,
    #tools=[answer_grader_tool],
)

# %%
rag_crew = Crew(
    agents=[Router_Agent, Retriever_Agent, Grader_agent, hallucination_grader, answer_grader],
    tasks=[router_task, retriever_task, grader_task, hallucination_task, answer_task],
    verbose=True,

)
# Out:
# 2025-02-17 20:35:42,133 - 5444 - __init__.py-__init__:537 - WARNING: Overriding of current TracerProvider is not allowed

# %%
inputs ={"question":"speed of light"}

# %%
result = rag_crew.kickoff(inputs=inputs)
# Out:
# # Agent: Router
# ## Task: Analyse the keywords in the question speed of lightBased on the keywords decide whether it is eligible for a vectorstore searchReturn a single word 'vectorstore' if it is eligible for vectorstore search.Do not provide any other premable or explaination.
#
#
# # Agent: Router
# ## Using tool: router_tool
# ## Tool Input:
# "{}"
# ## Tool Output:
# vectorstore
#
#
# You ONLY have access to the following tools, and should NEVER make up tools that are not listed here:
#
# Tool Name: router_tool
# Tool Arguments: {}
# Tool Description: Router Function
#
# IMPORTANT: Use the following format in your response:
#
# ```
# Thought: you should always think about what to do
# Action: the action to take, only one name of [router_tool], just the name, exactly as it's written.
# Action Input: the input to the action, just a simple JSON object, enclosed in curly braces, using " to wrap keys and values.
# Observation: the result of the action
# ```
#
# Once all necessary information is gathered, return the following format:
#
# ```
# Thought: I now know the final answer
# Final Answer: the final answer to the original input question
# ```
#
#
# # Agent: Router
# ## Final Answer:
# vectorstore
# ```
#
#
# # Agent: Retriever
# ## Task: Based on the response from the router task extract information for the question speed of light with the help of the respective tool.Use the web_serach_tool to retrieve information from the web in case the router task output is 'websearch'.Use the rag_tool to retrieve information from the vectorstore in case the router task output is 'vectorstore'.
#
#
# # Agent: Retriever
# ## Final Answer:
# The speed of light in a vacuum is approximately 299,792,458 meters per second (or about 186,282 miles per second).
#
#
# # Agent: Answer Grader
# ## Task: Based on the response from the retriever task for the quetion speed of light evaluate whether the retrieved content is relevant to the question.
#
#
# # Agent: Answer Grader
# ## Final Answer:
# yes
#
#
# # Agent: Hallucination Grader
# ## Task: Based on the response from the grader task for the quetion speed of light evaluate whether the answer is grounded in / supported by a set of facts.
#
#
# # Agent: Hallucination Grader
# ## Final Answer:
# yes
#
#
# # Agent: Answer Grader
# ## Task: Based on the response from the hallucination task for the quetion speed of light evaluate whether the answer is useful to resolve the question.If the answer is 'yes' return a clear and concise answer.If the answer is 'no' then perform a 'websearch' and return the response
#
#
# # Agent: Answer Grader
# ## Final Answer:
# The speed of light in a vacuum is approximately 299,792,458 meters per second (or about 186,282 miles per second).

# %%
print(result)
# Out:
# The speed of light in a vacuum is approximately 299,792,458 meters per second (or about 186,282 miles per second).
